# %% [markdown]
# <a href="https://colab.research.google.com/github/siriwat-heart/DWDM21/blob/main/Data_Preprocessing(Chapter3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # ทำงานกับข้อมูลลักษณะ ตาราง

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # จัดการไฟล์และ path

# %%
path = '/content/drive/My Drive/DWDM2021_DATA'
data_cases = pd.read_csv(os.path.join(path,'confirmed-cases.csv'))
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 526767  526768     27/7/2021  ...        สุพรรณบุรี               NaN
# 526768  526769     27/7/2021  ...        สุพรรณบุรี               NaN
# 526769  526770     27/7/2021  ...        สุพรรณบุรี               NaN
# 526770  526771     27/7/2021  ...        สุพรรณบุรี               NaN
# 526771  526772     27/7/2021  ...        สุพรรณบุรี               NaN
#
# [526772 rows x 11 columns]

# %% [markdown]
# ## Meta Data (Data ที่ใช้อธิบาย Data)

# %% [markdown]
# ## ชี้ข้อมูลในตาราง

# %% [markdown]
# ### ชี้แบบธรรมดา ใช้ [ชื่อ column][index]

# %%
data_cases['risk']
# Out:
# 0         คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         คนต่างชาติเดินทางมาจากต่างประเทศ
#                         ...
# 526767                    ทัณฑสถาน/เรือนจำ
# 526768                    ทัณฑสถาน/เรือนจำ
# 526769                    ทัณฑสถาน/เรือนจำ
# 526770                    ทัณฑสถาน/เรือนจำ
# 526771                    ทัณฑสถาน/เรือนจำ
# Name: risk, Length: 526772, dtype: object

# %%
data_cases['risk'][678]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %%
data_cases[['age','risk','sex']]
# Out:
#          age                              risk   sex
# 0       61.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 1       74.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 2       73.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 3       68.0  คนต่างชาติเดินทางมาจากต่างประเทศ   ชาย
# 4       66.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# ...      ...                               ...   ...
# 526767  34.0                  ทัณฑสถาน/เรือนจำ   ชาย
# 526768  32.0                  ทัณฑสถาน/เรือนจำ   ชาย
# 526769  26.0                  ทัณฑสถาน/เรือนจำ   ชาย
# 526770  32.0                  ทัณฑสถาน/เรือนจำ   ชาย
# 526771  37.0                  ทัณฑสถาน/เรือนจำ   ชาย
#
# [526772 rows x 3 columns]

# %% [markdown]
# ### ชี้แบบ .iloc[] (มองข้อมูลเป็น matrix)

# %%
data_cases.iloc[678,8]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %%
data_cases.iloc[-10:,4:9:2]
# Out:
#          age nationality              risk
# 526762  64.0         NaN  ทัณฑสถาน/เรือนจำ
# 526763  76.0         NaN  ทัณฑสถาน/เรือนจำ
# 526764  64.0         NaN  ทัณฑสถาน/เรือนจำ
# 526765  68.0         NaN  ทัณฑสถาน/เรือนจำ
# 526766  46.0         NaN  ทัณฑสถาน/เรือนจำ
# 526767  34.0         NaN  ทัณฑสถาน/เรือนจำ
# 526768  32.0         NaN  ทัณฑสถาน/เรือนจำ
# 526769  26.0         NaN  ทัณฑสถาน/เรือนจำ
# 526770  32.0         NaN  ทัณฑสถาน/เรือนจำ
# 526771  37.0         NaN  ทัณฑสถาน/เรือนจำ

# %%
data_cases.iloc[-10:,[3,4,8]]
# Out:
#         sex   age              risk
# 526762  ชาย  64.0  ทัณฑสถาน/เรือนจำ
# 526763  ชาย  76.0  ทัณฑสถาน/เรือนจำ
# 526764  ชาย  64.0  ทัณฑสถาน/เรือนจำ
# 526765  ชาย  68.0  ทัณฑสถาน/เรือนจำ
# 526766  ชาย  46.0  ทัณฑสถาน/เรือนจำ
# 526767  ชาย  34.0  ทัณฑสถาน/เรือนจำ
# 526768  ชาย  32.0  ทัณฑสถาน/เรือนจำ
# 526769  ชาย  26.0  ทัณฑสถาน/เรือนจำ
# 526770  ชาย  32.0  ทัณฑสถาน/เรือนจำ
# 526771  ชาย  37.0  ทัณฑสถาน/เรือนจำ

# %%
data_cases.describe()
# Out:
#                  No.            age
# count  526772.000000  475861.000000
# mean   263386.500000      35.532146
# std    152066.122338      16.175536
# min         1.000000       1.000000
# 25%    131693.750000      25.000000
# 50%    263386.500000      34.000000
# 75%    395079.250000      46.000000
# max    526772.000000     108.000000

# %%
from matplotlib import pyplot as plt

plt.boxplot(data_cases['age'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f9544649a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f9544654b50>,
#   <matplotlib.lines.Line2D at 0x7f954465b0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f954465bb90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f954465b650>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f95446540d0>,
#   <matplotlib.lines.Line2D at 0x7f9544654610>]}

# %% [markdown]
# # Missing Values
#
# * NaN = Not a Number
# * Null
# * NA = Not Available

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 526767  526768     27/7/2021  ...        สุพรรณบุรี               NaN
# 526768  526769     27/7/2021  ...        สุพรรณบุรี               NaN
# 526769  526770     27/7/2021  ...        สุพรรณบุรี               NaN
# 526770  526771     27/7/2021  ...        สุพรรณบุรี               NaN
# 526771  526772     27/7/2021  ...        สุพรรณบุรี               NaN
#
# [526772 rows x 11 columns]

# %%
data_cases.isnull()
# Out:
#           No.  announce_date  ...  province_of_onset  district_of_onset
# 0       False          False  ...              False               True
# 1       False          False  ...              False               True
# 2       False          False  ...              False              False
# 3       False          False  ...              False               True
# 4       False          False  ...              False               True
# ...       ...            ...  ...                ...                ...
# 526767  False          False  ...              False               True
# 526768  False          False  ...              False               True
# 526769  False          False  ...              False               True
# 526770  False          False  ...              False               True
# 526771  False          False  ...              False               True
#
# [526772 rows x 11 columns]

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ## Handling Missing Value 1 (ลบค่า missing)

# %%
plt.boxplot(data_cases['age'].dropna())
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f95441a8dd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f954412ee50>,
#   <matplotlib.lines.Line2D at 0x7f95441363d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9544136e90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9544136950>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f954412e3d0>,
#   <matplotlib.lines.Line2D at 0x7f954412e910>]}

# %%
data_cases.dropna()
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 47          48      6/3/2020  ...     กรุงเทพมหานคร           คลองตัน
# 124        125      6/3/2021  ...          ปทุมธานี           ธัญบุรี
# 161        162     17/3/2020  ...      สุราษฎร์ธานี             เมือง
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 186        187     18/3/2020  ...          ร้อยเอ็ด         เชียงขวัญ
# ...        ...           ...  ...               ...               ...
# 526522  526523     27/7/2021  ...     กรุงเทพมหานคร       บางขุนเทียน
# 526523  526524     27/7/2021  ...     กรุงเทพมหานคร         ลาดกระบัง
# 526524  526525     27/7/2021  ...     กรุงเทพมหานคร        บางกอกใหญ่
# 526525  526526     27/7/2021  ...     กรุงเทพมหานคร         บางคอแหลม
# 526526  526527     27/7/2021  ...     กรุงเทพมหานคร     สัมพันธ์ธวงศ์
#
# [373115 rows x 11 columns]

# %% [markdown]
# ## Quiz 3 ให้หาว่า การทำ dropna() ทำให้ข้อมูลหายไปกี่ %
#
#     size before drop = 1000
#     size after drop = 10
#     we loss 99% of data

# %%
after = data_cases.shape[0] - data_cases.dropna().shape[0]
after
# Out:
# 153657

# %%
data_af = (after/data_cases.shape[0])*100
data_af
# Out:
# 29.16954583766791

# %%
removed = data_cases.shape[0] - data_cases.dropna().shape[0]

print(f'size before drop = {data_cases.shape[0]}')
print(f'size after drop = {data_cases.dropna().shape[0]}')
print(f'we lost {100*(removed/data_cases.shape[0])}% of data')
# Out:
# size before drop = 526772
# size after drop = 373115
# we lost 29.16954583766791% of data

# %% [markdown]
# ## Handling Missing Value 1.5 (ลบค่า missing เฉพาะใน column ที่เราสนใจ)

# %%
data_cases_nomissingAge = data_cases.dropna(subset=['age'])

# %%
plt.boxplot(data_cases_nomissingAge['age'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f954369bbd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f95436a1c50>,
#   <matplotlib.lines.Line2D at 0x7f95436291d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9543629c90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9543629750>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f95436a11d0>,
#   <matplotlib.lines.Line2D at 0x7f95436a1710>]}

# %% [markdown]
# ## Quiz 3.1 ให้หาว่า การทำ dropna() แบบเลือก

# %%
removed = data_cases.shape[0] - data_cases_nomissingAge.shape[0]

print(f'size before drop = {data_cases.shape[0]}')
print(f'size after drop = {data_cases_nomissingAge.shape[0]}')
print(f'we lost {100*(removed/data_cases.shape[0])}% of data')
# Out:
# size before drop = 526772
# size after drop = 475861
# we lost 9.664712627094834% of data

# %% [markdown]
# ## Handling Missing Value 2 (แทนด้วย class ใหม่ (unknown))

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 526767  526768     27/7/2021  ...        สุพรรณบุรี               NaN
# 526768  526769     27/7/2021  ...        สุพรรณบุรี               NaN
# 526769  526770     27/7/2021  ...        สุพรรณบุรี               NaN
# 526770  526771     27/7/2021  ...        สุพรรณบุรี               NaN
# 526771  526772     27/7/2021  ...        สุพรรณบุรี               NaN
#
# [526772 rows x 11 columns]

# %%
data_cases[['risk']] = data_cases[['risk']].fillna('ไม่มีข้อมูล')

# %%
set(data_cases['risk'])
# Out:
# {'2.สัมผัสผู้ติดเชื้อ',
#  'ACF รองเมือง',
#  'ACF สนามกีฬาธูปะเตมีย์',
#  'ACF สนามกีฬาไทย-ญี่ปุ่น',
#  'ACF สีลม',
#  'ACF เคหะหลักสี่',
#  'Cluster Icon siam',
#  "Cluster Memory 90's กรุงเทพมหานคร",
#  'Cluster New Jazz กรุงเทพมหานคร',
#  'Cluster The Lounge Salaya',
#  'Cluster กรุงเทพมหานคร. คลองเตย',
#  'Cluster คลองเตย',
#  'Cluster งานมอเตอร์ โชว์',
#  'Cluster จนท. สนามบินสุวรรณภูมิ',
#  'Cluster จันทบุรี',
#  'Cluster จันทบุรี (ชาวกินี )',
#  'Cluster จันทบุรี (ชาวกินี)',
#  'Cluster ชลบุรี',
#  'Cluster ชลบุรี บริษัทไดกิ้น',
#  'Cluster ชลบุรี โรงเบียร์ 90',
#  'Cluster ตราด',
#  'Cluster ตราด ',
#  'Cluster ตลาดนนทบุรี',
#  'Cluster ตลาดบางพลี',
#  'Cluster ตลาดบางแค',
#  'Cluster ตลาดบางแค/คลองขวาง',
#  'Cluster ตลาดพรพัฒน์',
#  'Cluster ตลาดสี่มุมเมือง',
#  'Cluster ทัณฑสถานหญิงกลาง',
#  'Cluster ทัณฑสถานโรงพยาบาลราชทัณฑ์',
#  'Cluster ทันฑสถานบำบัดพิเศษกลาง',
#  'Cluster บริษัทศรีสวัสดิ์',
#  'Cluster บางแค',
#  'Cluster บ่อนพัทยา/ชลบุรี',
#  'Cluster บ่อนเทพารักษ์',
#  'Cluster บ่อนไก่อ่างทอง',
#  'Cluster ปากช่อง',
#  'Cluster ผับ Thonglor',
#  'Cluster มหาสารคาม',
#  'Cluster ระยอง',
#  'Cluster ระยอง วิริยะประกันภัย',
#  'Cluster สถานบันเทิงย่านทองหล่อ',
#  'Cluster สมุทรปราการ (โรงงาน บริษัทเมทัล โปรดักส์)',
#  'Cluster สมุทรปราการ GRP Hightech',
#  'Cluster สมุทรปราการ ตลาดเคหะบางพลี',
#  'Cluster สมุทรสาคร',
#  'Cluster ห้างแสงทอง (สายล่าง)',
#  'Cluster เครือคัสเซ่อร์พีคโฮลดิ้ง (CPG,CPH)',
#  'Cluster เรือนจำกลางคลองเปรม',
#  'Cluster เรือนจำพิเศษกรุงเทพ',
#  'Cluster เรือนจำพิเศษธนบุรี',
#  'Cluster เรือนจำพิเศษมีนบุรี',
#  'Cluster โรงงาน  Big Star',
#  'Cluster โรงงาน Big Star',
#  'Cluster โรงงาน QPP ประจวบฯ',
#  'Cluster โรงงาน standard can',
#  'Cluster โรงงานทำขนม บางขุนเทียน',
#  'Refer in',
#  'SHUI',
#  'Sandbox',
#  'State Quarantine',
#  'cluster ชลบุรี\n(อยู่ระหว่างการสอบสวน)',
#  'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน',
#  'คนต่างชาติเดินทางมาจากต่างประเทศ',
#  'คนไทยมาจากพื้นที่เสี่ยง',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คนไทยเดินทางมาจากต่างประเทศ',
#  'ค้นหาเชิงรุก',
#  'ตรวจก่อนทำหัตถการ',
#  'ตรวจสุขภาพแรงงานต่างด้าว',
#  'ตลาด',
#  'ทัณฑสถาน/เรือนจำ',
#  'บุคลากรด้านการแพทย์และสาธารณสุข',
#  'ปอดอักเสบ (Pneumonia)',
#  'ปอดอักเสบ Pneumonia',
#  'ผับหัวหิน',
#  'ผู้ติดเชื้อในประเทศ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ',
#  'ผู้ป่วย PUI',
#  'ผู้ป่วย กรุงเทพมหานคร',
#  'ผู้เดินทางมาจากพื้นที่เสี่ยง กรุงเทพมหานคร.',
#  'พิธีกรรมทางศาสนา',
#  'มาจากพื้นที่เสียง จ.ปทุมธานี',
#  'มาจากพื้นที่เสี่ยง',
#  'มาจากพื้นที่เสี่ยง จ.ปทุมธานี',
#  'รอประสาน',
#  'ระบุไม่ได้',
#  'ระหว่างการสอบสวนโรค',
#  'ระหว่างสอบสวน',
#  'รับจ้างขนของที่ตลาดท่ายาง',
#  'ร้านอาหาร',
#  'ศูนย์กักกัน ผู้ต้องกัก',
#  'สถานที่ทำงาน',
#  'สถานบันเทิง',
#  'สน.วัดพระยาไกร',
#  'สนามมวย',
#  'สัมผัสผู้ติดเชื้อยืนยัน\nอยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ติดเชื้อยืนยัน อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยที่ติดโควิด',
#  'สัมผัสผู้ป่วยยืนยัน',
#  'สัมผัสผู้ป่วยยืนยัน \n อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยัน (ยังไม่สามารถระบุได้)',
#  'สัมผัสผู้ป่วยยืนยัน ภายในครอบครัว/ชุมชน/เพื่อน',
#  'สัมผัสผู้ป่วยยืนยัน อยุ๋ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยัน อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยันเพื่อนร่วมงาน',
#  'สัมผัสผู้เดินทางจากต่างประเทศ',
#  'สัมผัสสามีสะอาด เขตบ้าน (รพ.มหาชัย 2)',
#  'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้',
#  'สัมผัสใกล้ชิดผู้ป่วยยันยันก่อนหน้า',
#  'สัมผัสใกล้ชิดผู้ป่วยยืนยันก่อนหน้า',
#  'สัมผัสในสถานพยาบาล',
#  'อยุ่ระหว่างสอบสวน',
#  'อยู่ระหว่างการสอบสวน',
#  'อยู่ระหว่างการสอบสวน\n',
#  'อยู่ระหว่างสอบสวน',
#  'อยู่ระหว่างสอบสวนโรค',
#  'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น',
#  'อาศัย/เดินทางไปในพื้นที่ที่มีการระบาด',
#  'อื่น',
#  'อื่นๆ',
#  'เดินทางมาจากพื้นที่จังหวัดเสี่ยง',
#  'เดินทางมาจากพื้นที่มีการระบาดของโรค',
#  'เดินทางมาจากพื้นที่เสี่ยง จ.กรุงเทพฯ จอมทอง',
#  'เดินทางมาจากพื้นที่เสี่ยงที่มีการระบาดของโรค',
#  'แรงงานต่างด้าวตรวจก่อนขึ้นทะเบียน',
#  'ไปยัง/มาจาก พื้นที่ระบาดกรุงเทพมหานครมหานคร',
#  'ไปยังพื้นที่ที่มีการระบาด',
#  'ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว',
#  'ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน',
#  'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต',
#  'ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar',
#  'ไปแหล่งชุมชน/สถานที่คนหนาแน่น',
#  'ไม่มีข้อมูล'}

# %% [markdown]
# ## Handling Missing Value 3 (แทนด้วย class ใหม่ (ค่าที่เหมาะสม))

# %%
set(data_cases['Unit'])
# Out:
# {' วัน', ' เดือน', nan, 'ปี', 'วัน', 'เดือน'}

# %%
data_cases[['Unit']] = data_cases[['Unit']].fillna('ปี?')

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ## Handling Missing Value 4 (เเทนด้วย ค่ากลาง)

# %% [markdown]
# ถ้าเป็น numeric ใช้ mean

# %%
# หา mean
data_cases [['age']].mean()
# เติม mean ลงไปแทนค่า missing
# Out:
# age    35.532146
# dtype: float64

# %%
data_cases [['age']].dropna().mean()
# Out:
# age    35.532146
# dtype: float64

# %%
# หา mean
avg_age = data_cases [['age']].mean()
# เติม mean ลงไปแทนค่า missing
data_cases [['age']] = data_cases [['age']].fillna(avg_age)

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                      False
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['age']].mean()
# Out:
# age    35.532146
# dtype: float64

# %% [markdown]
# ถ้าเป็น norinal (ตัวหนังสือ) จะใช้ mode

# %%
data_cases[['nationality']].mode()
# Out:
#   nationality
# 0    Thailand

# %%
data_cases[['nationality']].mode().iloc[0,0]
# Out:
# 'Thailand'

# %%
data_cases['nationality'].mode()
# Out:
# 0    Thailand
# dtype: object

# %%
data_cases.head(20)
# Out:
#     No. announce_date  ... province_of_onset district_of_onset
# 0     1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1     2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2     3     22/1/2020  ...            นครปฐม             เมือง
# 3     4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4     5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5     6     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6     7     26/1/2020  ...     กรุงเทพมหานคร               NaN
# 7     8     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 8     9     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 9    10     28/1/2020  ...           นนทบุรี               NaN
# 10   11     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 11   12     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 12   13     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 13   14     28/1/2020  ...            ภูเก็ต             เมือง
# 14   15     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 15   16     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 16   17     31/1/2020  ...         เชียงใหม่             หางดง
# 17   18     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 18   19     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 19   20      4/2/2020  ...     กรุงเทพมหานคร               NaN
#
# [20 rows x 11 columns]

# %% [markdown]
# ## Handling Missing Value 5 (แทนด้วย ค่ากลางของ samples ใน class เดียว)

# %%
data_cases2 = pd.read_csv(os.path.join(path,'confirmed-cases.csv'))
data_cases2
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 526767  526768     27/7/2021  ...        สุพรรณบุรี               NaN
# 526768  526769     27/7/2021  ...        สุพรรณบุรี               NaN
# 526769  526770     27/7/2021  ...        สุพรรณบุรี               NaN
# 526770  526771     27/7/2021  ...        สุพรรณบุรี               NaN
# 526771  526772     27/7/2021  ...        สุพรรณบุรี               NaN
#
# [526772 rows x 11 columns]

# %% [markdown]
# ### Select data by value [PD]

# %% [markdown]
# การเลือก record

# %%
data_cases2['risk'] == 'ทัณฑสถาน/เรือนจำ'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 526767     True
# 526768     True
# 526769     True
# 526770     True
# 526771     True
# Name: risk, Length: 526772, dtype: bool

# %%
data_cases2[data_cases2['risk'] == 'ทัณฑสถาน/เรือนจำ']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 100018  100019     16/5/2021  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 100019  100020     16/5/2021  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 101468  101469     17/5/2021  ...               NaN               NaN
# 101469  101470     17/5/2021  ...               NaN               NaN
# 101470  101471     17/5/2021  ...               NaN               NaN
# ...        ...           ...  ...               ...               ...
# 526767  526768     27/7/2021  ...        สุพรรณบุรี               NaN
# 526768  526769     27/7/2021  ...        สุพรรณบุรี               NaN
# 526769  526770     27/7/2021  ...        สุพรรณบุรี               NaN
# 526770  526771     27/7/2021  ...        สุพรรณบุรี               NaN
# 526771  526772     27/7/2021  ...        สุพรรณบุรี               NaN
#
# [41576 rows x 11 columns]

# %%
blist_age70up = data_cases2['age'] > 70

# %%
blist_female = data_cases2['sex'] == 'หญิง'
blist_female
# Out:
# 0          True
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 526767    False
# 526768    False
# 526769    False
# 526770    False
# 526771    False
# Name: sex, Length: 526772, dtype: bool

# %%
blist_age70up & blist_female
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 526767    False
# 526768    False
# 526769    False
# 526770    False
# 526771    False
# Length: 526772, dtype: bool

# %%
data_cases2[blist_age70up & blist_female]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 7            8     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 476        477     22/3/2020  ...     กรุงเทพมหานคร         ภาษีเจริญ
# 564        565     22/3/2020  ...           นนทบุรี               NaN
# ...        ...           ...  ...               ...               ...
# 526397  526398     27/7/2021  ...     กรุงเทพมหานคร           มีนบุรี
# 526424  526425     27/7/2021  ...     กรุงเทพมหานคร             พญาไท
# 526426  526427     27/7/2021  ...     กรุงเทพมหานคร            จอมทอง
# 526470  526471     27/7/2021  ...     กรุงเทพมหานคร            บางบอน
# 526479  526480     27/7/2021  ...     กรุงเทพมหานคร            ดินแดง
#
# [6540 rows x 11 columns]

# %% [markdown]
# ## Quiz 4 + HW
#
# เลือก records ต่อไปนี้
#
# 1. records ที่ กักตัวที่ขอนเเก่น
# 2. records ที่ กักตัวที่ขอนแก่น+โคราช+อุดร
# 3. records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม
# 4. records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่
# 5. หาอายุเฉลี่ย

# %% [markdown]
# ## ตอบ

# %% [markdown]
# ### ข้อ 1

# %%
data_cases2[data_cases2['province_of_isolation']=='ขอนแก่น']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 520695  520696     27/7/2021  ...           ขอนแก่น           ภูเวียง
# 520696  520697     27/7/2021  ...           ขอนแก่น           ภูเวียง
# 520697  520698     27/7/2021  ...           ขอนแก่น             ชุมแพ
# 520698  520699     27/7/2021  ...           ขอนแก่น             ชุมแพ
# 526540  526541     27/7/2021  ...           ขอนแก่น               NaN
#
# [3834 rows x 11 columns]

# %% [markdown]
# ## ข้อ 2

# %%
data_cases2[(data_cases2['province_of_isolation']=='ขอนแก่น') | 
            (data_cases2['province_of_isolation']=='นครราชสีมา') | 
            (data_cases2['province_of_isolation']=='อุดรธานี')]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 189        190     18/3/2020  ...        นครราชสีมา             พิมาย
# 207        208     18/3/2020  ...     กรุงเทพมหานคร               NaN
# 212        213     18/3/2020  ...        นครราชสีมา       วังน้ำเขียว
# 284        285     20/3/2020  ...        นครราชสีมา   เมืองนครราชสีมา
# ...        ...           ...  ...               ...               ...
# 521931  521932     27/7/2021  ...               NaN               NaN
# 521932  521933     27/7/2021  ...               NaN               NaN
# 521933  521934     27/7/2021  ...               NaN               NaN
# 521934  521935     27/7/2021  ...               NaN               NaN
# 526540  526541     27/7/2021  ...           ขอนแก่น               NaN
#
# [11003 rows x 11 columns]

# %% [markdown]
# ### ข้อ 3

# %%
data_cases2[(data_cases2['district_of_onset']=='กรุงเทพมหานคร') & (data_cases2['sex']=='หญิง')]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 292        293     20/3/2020  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 318        319     20/3/2020  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 1928      1929      3/4/2020  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 30541    30542      9/4/2021  ...            ชลบุรี     กรุงเทพมหานคร
# 208455  208456     18/6/2021  ...       สมุทรปราการ     กรุงเทพมหานคร
# ...        ...           ...  ...               ...               ...
# 429001  429002     21/7/2021  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 461987  461988     23/7/2021  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 471588  471589     24/7/2021  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 471589  471590     24/7/2021  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 488250  488251     25/7/2021  ...        ฉะเชิงเทรา     กรุงเทพมหานคร
#
# [77 rows x 11 columns]

# %% [markdown]
# ### ข้อ 4

# %%
blist_male = data_cases2['sex'] == 'ชาย'
blist_age = data_cases2['age'] >=18
blist_age2 = data_cases2['age'] <=22
blist_CM = data_cases2['province_of_isolation'] == 'เชียงใหม่'

# %%
data_cases2[blist_male & blist_age & blist_age2 & blist_CM]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 1407      1408     30/3/2020  ...         เชียงใหม่             เมือง
# 30340    30341      9/4/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# 31499    31500     10/4/2021  ...         เชียงใหม่               NaN
# 31500    31501     10/4/2021  ...         เชียงใหม่               NaN
# 31501    31502     10/4/2021  ...         เชียงใหม่               NaN
# ...        ...           ...  ...               ...               ...
# 481961  481962     25/7/2021  ...         เชียงใหม่          เชียงดาว
# 497281  497282     26/7/2021  ...         เชียงใหม่          เชียงดาว
# 497302  497303     26/7/2021  ...         เชียงใหม่             หางดง
# 512632  512633     27/7/2021  ...         เชียงใหม่               NaN
# 512648  512649     27/7/2021  ...         เชียงใหม่             หางดง
#
# [413 rows x 11 columns]

# %% [markdown]
# ### ข้อ 5

# %%
blist_provinceKKC = data_cases2['province_of_onset'] == 'ขอนแก่น'
data_cases2provinceKKC = data_cases2[blist_provinceKKC]
data_cases2provinceKKC
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 520696  520697     27/7/2021  ...           ขอนแก่น           ภูเวียง
# 520697  520698     27/7/2021  ...           ขอนแก่น             ชุมแพ
# 520698  520699     27/7/2021  ...           ขอนแก่น             ชุมแพ
# 524699  524700     27/7/2021  ...           ขอนแก่น            สีชมพู
# 526540  526541     27/7/2021  ...           ขอนแก่น               NaN
#
# [3234 rows x 11 columns]

# %%
data_cases2provinceKKC[['age']].mean()
# Out:
# age    34.173587
# dtype: float64

# %%
KK_cases = data_cases2['province_of_onset'] == 'ขอนแก่น'
KK_mean = data_cases2[KK_cases]['age'].mean()
KK_mean
# Out:
# 34.17358726194193

# %%
data_cases2[KK_cases]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 520696  520697     27/7/2021  ...           ขอนแก่น           ภูเวียง
# 520697  520698     27/7/2021  ...           ขอนแก่น             ชุมแพ
# 520698  520699     27/7/2021  ...           ขอนแก่น             ชุมแพ
# 524699  524700     27/7/2021  ...           ขอนแก่น            สีชมพู
# 526540  526541     27/7/2021  ...           ขอนแก่น               NaN
#
# [3234 rows x 11 columns]

# %%
data_KK = data_cases2[KK_cases]
data_KK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_KK[['age']] = data_KK[['age']].fillna(KK_mean)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_KK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                      False
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_KK
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 520696  520697     27/7/2021  ...           ขอนแก่น           ภูเวียง
# 520697  520698     27/7/2021  ...           ขอนแก่น             ชุมแพ
# 520698  520699     27/7/2021  ...           ขอนแก่น             ชุมแพ
# 524699  524700     27/7/2021  ...           ขอนแก่น            สีชมพู
# 526540  526541     27/7/2021  ...           ขอนแก่น               NaN
#
# [3234 rows x 11 columns]

# %%
# หาค่า mean ของเชียงใหม่
CM_cases = data_cases2['province_of_onset'] == 'เชียงใหม่'
CM_mean = data_cases2[CM_cases]['age'].mean()

# เลือกมาเฉพาะ data เชียงใหม่
data_CM = data_cases2[CM_cases]

# เติมค่า mean แทน missing
data_CM[['age']] = data_CM[['age']].fillna(CM_mean)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_CM
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 16          17     31/1/2020  ...         เชียงใหม่             หางดง
# 91          92     15/3/2020  ...         เชียงใหม่            แม่ริม
# 185        186     18/3/2020  ...         เชียงใหม่          นครพิงค์
# 192        193     18/3/2020  ...         เชียงใหม่               NaN
# 252        253     19/3/2020  ...         เชียงใหม่               NaN
# ...        ...           ...  ...               ...               ...
# 512663  512664     27/7/2021  ...         เชียงใหม่           สันทราย
# 512664  512665     27/7/2021  ...         เชียงใหม่          สันกำแพง
# 512665  512666     27/7/2021  ...         เชียงใหม่         สันป่าตอง
# 512666  512667     27/7/2021  ...         เชียงใหม่             หางดง
# 512667  512668     27/7/2021  ...         เชียงใหม่               NaN
#
# [4120 rows x 11 columns]

# %% [markdown]
# ## ต่อตารางแนวแกน Y [PD]

# %%
data_CMKK = pd.concat([data_CM,data_KK])
data_CMKK
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 16          17     31/1/2020  ...         เชียงใหม่             หางดง
# 91          92     15/3/2020  ...         เชียงใหม่            แม่ริม
# 185        186     18/3/2020  ...         เชียงใหม่          นครพิงค์
# 192        193     18/3/2020  ...         เชียงใหม่               NaN
# 252        253     19/3/2020  ...         เชียงใหม่               NaN
# ...        ...           ...  ...               ...               ...
# 520696  520697     27/7/2021  ...           ขอนแก่น           ภูเวียง
# 520697  520698     27/7/2021  ...           ขอนแก่น             ชุมแพ
# 520698  520699     27/7/2021  ...           ขอนแก่น             ชุมแพ
# 524699  524700     27/7/2021  ...           ขอนแก่น            สีชมพู
# 526540  526541     27/7/2021  ...           ขอนแก่น               NaN
#
# [7354 rows x 11 columns]

# %% [markdown]
# ## Handling Missing Value 5 (แทนด้วย ค่ากลางของ samples ใน class เดียวกัน) (ต่อ)

# %%
data_cases2
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 526767  526768     27/7/2021  ...        สุพรรณบุรี               NaN
# 526768  526769     27/7/2021  ...        สุพรรณบุรี               NaN
# 526769  526770     27/7/2021  ...        สุพรรณบุรี               NaN
# 526770  526771     27/7/2021  ...        สุพรรณบุรี               NaN
# 526771  526772     27/7/2021  ...        สุพรรณบุรี               NaN
#
# [526772 rows x 11 columns]

# %%
data_cases2[['province_of_onset']] = data_cases2[['province_of_onset']].fillna('ไม่มีข้อมูล')

# %%
all_cities = set(data_cases2['province_of_onset'])

# %%
all_cities
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธ์ุ',
#  'กาฬสิินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่่น',
#  'จ.ปัตตานี',
#  'จังหวัดร้อยเอ็ด',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชลบุุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชััยภูมิ',
#  'ชุมพร',
#  'ชุุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'ธารโต',
#  'นคนปฐม',
#  'นคปฐม',
#  'นครนาชสีมา',
#  'นครนายก',
#  'นครปฐม',
#  'นครประฐม',
#  'นครพนม',
#  'นครราชธสีมา',
#  'นครราชสีมา',
#  'นครศรธรรมาช',
#  'นครศรี',
#  'นครศรีธรรมราช',
#  'นครศรีธรรรมราช',
#  'นครศรีราชสีมา',
#  'นครศรีีธรรมราช',
#  'นครสวรรค์',
#  'นครสววรค์',
#  'นตรปฐม',
#  'นนทบุรี',
#  'นนทุบรี',
#  'นราธิวาส',
#  'นาราธิวาส',
#  'นาวัง',
#  'น่าน',
#  'บางกะปิ',
#  'บึงกาฬ',
#  'บึงโขงหลง',
#  'บึึงกาฬ',
#  'บุรีรัมย์',
#  'บุรีรัยม์',
#  'บ้านหลวง',
#  'ปทุมทานี',
#  'ปทุมธานี',
#  'ปทุมธานีี',
#  'ปทุุมธานี',
#  'ประจวบครีขันธ์',
#  'ประจวบคีรีขันธื',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปลายพระยา',
#  'ปัตตานี',
#  'ปัตตานี\u200b',
#  'ปัว',
#  'พม่า',
#  'พระนครศรียุธยา',
#  'พระนครศรีอยุทธยา',
#  'พระนครศรีอยุธนา',
#  'พระนครศรีอยุธยา',
#  'พระนครศีรอยุธยา',
#  'พระนครศีอยุธยา',
#  'พระนตรศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'ภูเพียง',
#  'มหาสารคราม',
#  'มหาสารคาม',
#  'มาเลเซีย',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยานนาวา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้องกวาง',
#  'ร้อยเอ็ด',
#  'ร้อยเอ็็ด',
#  'ร้อยเอ้ด',
#  'ร้้อยเอ็ด',
#  'ลพบรี',
#  'ลพบุรี',
#  'ลพบุุรี',
#  'ลอง',
#  'ลำปาง',
#  'ลำพูน',
#  'วังชิ้น',
#  'ศรีษะเกษ',
#  'ศรีสะเกษ',
#  'ศรีีสะเกษ',
#  'ศีรษะเกษ',
#  'ศีรสะเกษ',
#  'สกลนคร',
#  'สงขขลา',
#  'สงขลา',
#  'สงขลา\u200b',
#  'สตูล',
#  'สถานที่ทำงาน',
#  'สมทรสาคร',
#  'สมุทปราการ',
#  'สมุทรปราการ',
#  'สมุทรปาการ',
#  'สมุทรสงคราม',
#  'สมุทรสงคราม.',
#  'สมุทรสาคร',
#  'สมุทราปราการ',
#  'สมุทราสาคร',
#  'สมุทสงคราม',
#  'สมุทสาคร',
#  'สมุุทรปราการ',
#  'สมุุทรสงคราม',
#  'สมุุทรสาคร',
#  'สมุุทสาคร',
#  'สระบุรี',
#  'สระบุุรี',
#  'สระแก้ว',
#  'สรแก้ว',
#  'สอง',
#  'สองแคว',
#  'สิงห์บุรี',
#  'สุทรปราการ',
#  'สุพรรณบุรี',
#  'สุมทรสาคร',
#  'สุมุทรปราการ',
#  'สุมุทรสาคร',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุุราษฎร์ธานี',
#  'สุโขทัย',
#  'สูงเม่น',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'หนองบัวลำภูู',
#  'หนองบัวลำำภู',
#  'หนองบััวลำภู',
#  'หนองม่วงไข่',
#  'อยุธยา',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุดรธานีี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราขธานี',
#  'อุบลราชธานี',
#  'อุยุธยา',
#  'อุุดรธาน',
#  'อุุดรธานี',
#  'อุุตรดิตถ์',
#  'อุุทัยธานี',
#  'อ่างทอง',
#  'ูภูเก็ต',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เด่นชัย',
#  'เพชบุรี',
#  'เพชรบุรี',
#  'เพชรบูรณ์',
#  'เพชรบูลย์',
#  'เพรชบุรี',
#  'เพรบุรี',
#  'เมือง',
#  'เมืองน่าน',
#  'เรือ',
#  'เลย',
#  'เวียงจันทร์',
#  'เวียงสา',
#  'แพร่',
#  'แม่ฮ่องสอน',
#  'ไม่มีข้อมูล',
#  'ไม่ระบุ'}

# %%
fixed_cities = []

for city in all_cities:
    # หาค่า mean ของเชียงใหม่
    X_cases = data_cases2['province_of_onset'] == city
    X_mean = data_cases2[X_cases]['age'].mean()

    # เลือกมาเฉพาะ data เชียงใหม่
    data_X = data_cases2[X_cases]

    # เติมค่า mean แทน missing
    data_X[['age']] = data_X[['age']].fillna(X_mean)

    fixed_cities.append(data_X)


data_cases2_nomissingage = pd.concat(fixed_cities)

# %%
data_cases2_nomissingage
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 24          25      4/2/2020  ...       สมุทรปราการ               NaN
# 26          27      8/2/2020  ...       สมุทรปราการ               NaN
# 30          31      8/2/2020  ...       สมุทรปราการ               NaN
# 33          34     15/2/2020  ...       สมุทรปราการ               NaN
# 98          99     15/3/2020  ...       สมุทรปราการ               NaN
# ...        ...           ...  ...               ...               ...
# 513250  513251     27/7/2021  ...           อุยุธยา               NaN
# 393279  393280     18/7/2021  ...   พระนตรศรีอยุธยา          บางปะหัน
# 393280  393281     18/7/2021  ...   พระนตรศรีอยุธยา          บางปะหัน
# 393335  393336     18/7/2021  ...   พระนตรศรีอยุธยา   พระนครศรีอยุธยา
# 394243  394244     18/7/2021  ...   พระนตรศรีอยุธยา            มหาราช
#
# [526772 rows x 11 columns]

# %%
data_cases2_nomissingage.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_cases2_nomissingage[['age']] = data_cases2_nomissingage[['age']].fillna(data_cases2_nomissingage['age'].mean())

# %%
data_cases2_nomissingage.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                      False
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_cases2_nomissingage
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 24          25      4/2/2020  ...       สมุทรปราการ               NaN
# 26          27      8/2/2020  ...       สมุทรปราการ               NaN
# 30          31      8/2/2020  ...       สมุทรปราการ               NaN
# 33          34     15/2/2020  ...       สมุทรปราการ               NaN
# 98          99     15/3/2020  ...       สมุทรปราการ               NaN
# ...        ...           ...  ...               ...               ...
# 513250  513251     27/7/2021  ...           อุยุธยา               NaN
# 393279  393280     18/7/2021  ...   พระนตรศรีอยุธยา          บางปะหัน
# 393280  393281     18/7/2021  ...   พระนตรศรีอยุธยา          บางปะหัน
# 393335  393336     18/7/2021  ...   พระนตรศรีอยุธยา   พระนครศรีอยุธยา
# 394243  394244     18/7/2021  ...   พระนตรศรีอยุธยา            มหาราช
#
# [526772 rows x 11 columns]

# %%
data_cases2_nomissingage = data_cases2_nomissingage.sort_values(by=['No.'])

# %%
data_cases2_nomissingage
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 526767  526768     27/7/2021  ...        สุพรรณบุรี               NaN
# 526768  526769     27/7/2021  ...        สุพรรณบุรี               NaN
# 526769  526770     27/7/2021  ...        สุพรรณบุรี               NaN
# 526770  526771     27/7/2021  ...        สุพรรณบุรี               NaN
# 526771  526772     27/7/2021  ...        สุพรรณบุรี               NaN
#
# [526772 rows x 11 columns]

# %%
from matplotlib import pyplot as pl

# %%
data_dict = plt.boxplot(data_cases2_nomissingage['age'])

# %%
data_dict # curly brackets
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f95433636d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f9543351750>,
#   <matplotlib.lines.Line2D at 0x7f9543351c90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f95432e6790>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f95432e6250>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f9543363c90>,
#   <matplotlib.lines.Line2D at 0x7f9543351210>]}

# %%
data_dict['boxes']

# %%
data_dict['boxes'][0]

# %%
data_dict['boxes'][0].get_ydata()
# Out:
# array([26., 26., 44., 44., 26.])

# %%
Q1 = data_dict['boxes'][0].get_ydata()[0]

# %%
Q1
# Out:
# 26.0

# %%
data_dict['fliers'][0].get_ydata()
# Out:
# array([74., 73., 73., ..., 80., 74., 76.])

# %%
data_dict['caps'][0].get_ydata()
# Out:
# array([1., 1.])

# %%
data_dict['caps'][0].get_ydata()[0]
# Out:
# 1.0

# %%
data_dict['caps'][1].get_ydata()
# Out:
# array([71., 71.])

# %%
cap1 = data_cases2_nomissingage['age'] >= data_dict['caps'][0].get_ydata()[0]
cap2 = data_cases2_nomissingage['age'] <= data_dict['caps'][1].get_ydata()[0]

data_cases2_nomissingage_nooutlier = data_cases2_nomissingage[cap1 & cap2]
data_cases2_nomissingage_nooutlier
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5            6     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6            7     26/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 526767  526768     27/7/2021  ...        สุพรรณบุรี               NaN
# 526768  526769     27/7/2021  ...        สุพรรณบุรี               NaN
# 526769  526770     27/7/2021  ...        สุพรรณบุรี               NaN
# 526770  526771     27/7/2021  ...        สุพรรณบุรี               NaN
# 526771  526772     27/7/2021  ...        สุพรรณบุรี               NaN
#
# [516202 rows x 11 columns]

# %%
data_dict = plt.boxplot(data_cases2_nomissingage_nooutlier['age'])

# %%
data_cases2_nomissingage[data_cases2_nomissingage['province_of_onset'] != 'ลอง']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 526767  526768     27/7/2021  ...        สุพรรณบุรี               NaN
# 526768  526769     27/7/2021  ...        สุพรรณบุรี               NaN
# 526769  526770     27/7/2021  ...        สุพรรณบุรี               NaN
# 526770  526771     27/7/2021  ...        สุพรรณบุรี               NaN
# 526771  526772     27/7/2021  ...        สุพรรณบุรี               NaN
#
# [526766 rows x 11 columns]

# %% [markdown]
# # Quiz 5
#
# เขียนฟังก์ชั่น คำนวณ หา Q1,Q2,Q3,IQR,min,max โดยรับ input เป็น output ของ boxplot
#
# ```python
# def box_vals(box_out_dict):
#     #your code1
#     .
#     .
#     .
#     #your codex
#     return q1,q2,q3,iqr,vmin,vmix
# ```

# %%
def box_vals(box_out_dict):
    # การหาค่า
    q1 = data_dict['boxes'][0].get_ydata()[0]
    q2 = data_dict['boxes'][0].get_ydata()[1]
    q3 = data_dict['boxes'][0].get_ydata()[2]
    iqr = q3 - q1
    vmin = min(data_dict['boxes'][0].get_ydata())
    vmax = max(data_dict['boxes'][0].get_ydata())
    # การแสดงผล
    print('ใช้ฟังก์ชันแล้วจะได้ผลลัพธ์ดังนี้')
    print(f'Q1 = {q1}')
    print(f'Q2 = {q2}')
    print(f'Q3 = {q3}')
    print(f'IQR = {iqr}')
    print(f'min = {vmin}')
    print(f'max = {vmax}')
   
    ##print('ค่าของ Q1,Q2,Q3,IQR,vmin,vmax ตามลำดับ ดังนี้')
    return ##q1,q2,q3,iqr,vmin,vmax

# %%
box_vals(data_dict)
# Out:
# ใช้ฟังก์ชันแล้วจะได้ผลลัพธ์ดังนี้
# Q1 = 25.0
# Q2 = 25.0
# Q3 = 43.0
# IQR = 18.0
# min = 25.0
# max = 43.0

# %%
q1 = data_dict['boxes'][0].get_ydata()[0]
q1
# Out:
# 25.0

# %%
q2 = data_dict['boxes'][0].get_ydata()[1]
q2
# Out:
# 25.0

# %%
q3 = data_dict['boxes'][0].get_ydata()[2]
q3
# Out:
# 43.0
