# %% [markdown]
# <a href="https://colab.research.google.com/github/siriwat-heart/DWDM21/blob/main/Homeworks_InfoD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![HW info.jpg](data:image/jpeg;base64,...)
